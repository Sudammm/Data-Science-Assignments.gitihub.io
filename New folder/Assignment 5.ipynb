# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris

# %%
iris=load_iris()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df=pd.DataFrame(data=iris.data,columns=iris.feature_names)
df['target']=iris.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
#cross_val_score
help(LogisticRegression())
# Out:
# Help on LogisticRegression in module sklearn.linear_model._logistic object:
#
# class LogisticRegression(sklearn.linear_model._base.LinearClassifierMixin, sklearn.linear_model._base.SparseCoefMixin, sklearn.base.BaseEstimator)
#  |  LogisticRegression(penalty='l2', *, dual=False, tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, solver='lbfgs', max_iter=100, multi_class='auto', verbose=0, warm_start=False, n_jobs=None, l1_ratio=None)
#  |
#  |  Logistic Regression (aka logit, MaxEnt) classifier.
#  |
#  |  In the multiclass case, the training algorithm uses the one-vs-rest (OvR)
#  |  scheme if the 'multi_class' option is set to 'ovr', and uses the
#  |  cross-entropy loss if the 'multi_class' option is set to 'multinomial'.
#  |  (Currently the 'multinomial' option is supported only by the 'lbfgs',
#  |  'sag', 'saga' and 'newton-cg' solvers.)
#  |
#  |  This class implements regularized logistic regression using the
# ...

# %%
#Logistics Regression
score_log=np.mean(cross_val_score(LogisticRegression(solver="liblinear", multi_class="ovr"),iris.data,iris.target,cv=10))
score_log
# Out:
# 0.9533333333333334

# %%
#SVM
score_svm=np.mean(cross_val_score(SVC(gamma='auto'),iris.data,iris.target,cv=10))
score_svm
# Out:
# 0.9800000000000001

# %%
#DecisionTree
from sklearn.tree import DecisionTreeClassifier
score_tree=np.mean(cross_val_score(DecisionTreeClassifier(),iris.data,iris.target))
score_tree
# Out:
# 0.9600000000000002

# %%
# Random forest
score_forest=np.mean(cross_val_score(RandomForestClassifier(n_estimators=40),iris.data,iris.target,cv=10))
score_forest
# Out:
# 0.9533333333333334

# %%
print(f'score_log:{score_log},\nscore_SVM:{score_svm},\nscore_tree:{score_tree},\nscore_forest:{score_forest}')
# Out:
# score_log:0.9533333333333334,
# score_SVM:0.9800000000000001,
# score_tree:0.9600000000000002,
# score_forest:0.9533333333333334
